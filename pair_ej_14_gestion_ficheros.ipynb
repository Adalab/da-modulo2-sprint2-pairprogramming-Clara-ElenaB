# %%
import xml.etree.ElementTree as ET
import pandas as pd
import json

# %% [markdown]
# - Hacer las importaciones necesarias para abrir un archivo de tipo "csv" en Pandas.
#
# - Abrir el archivo, creando un Dataframe. Aseguraros de que no incluye la columna "Unnamed: 0".

# %%
df_video= pd.read_csv("videogames.csv", index_col = 0)
df_video
# Out:
#                                       name  \
# 0                               Spider-Man
# 1                   Red Dead Redemption II
# 2                       Grand Theft Auto V
# 3                               God of War
# 4               Uncharted 4: A Thief's End
# ...                                    ...
# 20798  Enjoy Your Power, Enjoy Your Choice
# 20799                           RedSun2020
# 20800                              Shutter
# 20801                    The Music Machine
# 20802                              Cryptic
#
#                                                      url    year certificate  \
# 0      https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1      https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2      https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3      https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4      https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
# ...                                                  ...     ...         ...
# 20798  https://www.imdb.com/title/tt3845606/?ref_=adv...  2014.0         NaN
# 20799  https://www.imdb.com/title/tt0790739/?ref_=adv...  2004.0         NaN
# 20800  https://www.imdb.com/title/tt5119948/?ref_=adv...  2015.0         NaN
# 20801  https://www.imdb.com/title/tt5142082/?ref_=adv...  2015.0         NaN
# 20802  https://www.imdb.com/title/tt10964974/?ref_=ad...  2020.0         NaN
#
#        rating   votes                                               plot  \
# 0         9.2  20,759  When a new villain threatens New York City, Pe...
# 1         9.7  35,703  Amidst the decline of the Wild West at the tur...
# 2         9.5  59,986  Three very different criminals team up for a s...
# 3         9.6  26,118  After wiping out the gods of Mount Olympus, Kr...
# 4         9.5  28,722  Thrown back into the dangerous underworld he'd...
# ...       ...     ...                                                ...
# 20798     NaN     NaN                                         Add a Plot
# 20799     NaN     NaN  Joseph gets kidnapped and it's the player's jo...
# 20800     NaN     NaN  A tech support man who uses a drone to investi...
# 20801     NaN     NaN  A young teenage girl and the ghost of a dead m...
# 20802     NaN     NaN  Kidnapped by an insane man and dragged into a ...
#
#        Action  Adventure  Comedy  Crime  Family  Fantasy  Mystery  Sci-Fi  \
# 0        True       True   False  False   False     True    False   False
# 1        True       True   False   True   False    False    False   False
# 2        True      False   False   True   False    False    False   False
# 3        True       True   False  False   False    False    False   False
# 4        True       True   False  False   False    False    False   False
# ...       ...        ...     ...    ...     ...      ...      ...     ...
# 20798   False      False   False  False   False    False    False   False
# 20799   False      False   False  False   False    False    False   False
# 20800   False      False   False  False   False    False    False   False
# 20801   False      False   False  False   False    False    False   False
# 20802   False      False   False  False   False    False    False   False
#
#        Thriller
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 20798      True
# 20799      True
# 20800      True
# 20801      True
# 20802      True
#
# [20803 rows x 16 columns]

# %% [markdown]
# - Una vez creado el Dataframe, muestra las 10 primeras filas.

# %%
df_video.head(10)
# Out:
#                          name  \
# 0                  Spider-Man
# 1      Red Dead Redemption II
# 2          Grand Theft Auto V
# 3                  God of War
# 4  Uncharted 4: A Thief's End
# 5     The Last of Us: Part II
# 6      Horizon Forbidden West
# 7              The Last of Us
# 8       Detroit: Become Human
# 9             Death Stranding
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
# 5  https://www.imdb.com/title/tt6298000/?ref_=adv...  2020.0           M
# 6  https://www.imdb.com/title/tt12496904/?ref_=ad...  2022.0           T
# 7  https://www.imdb.com/title/tt2140553/?ref_=adv...  2013.0           M
# 8  https://www.imdb.com/title/tt5158314/?ref_=adv...  2018.0           M
# 9  https://www.imdb.com/title/tt5807606/?ref_=adv...  2019.0           M
#
#    rating   votes                                               plot  Action  \
# 0     9.2  20,759  When a new villain threatens New York City, Pe...    True
# 1     9.7  35,703  Amidst the decline of the Wild West at the tur...    True
# 2     9.5  59,986  Three very different criminals team up for a s...    True
# 3     9.6  26,118  After wiping out the gods of Mount Olympus, Kr...    True
# 4     9.5  28,722  Thrown back into the dangerous underworld he'd...    True
# 5     8.5  30,460  Five years after the events of The Last of Us,...    True
# 6     9.2   2,979  Aloy treks into an arcane region and faces new...    True
# 7     9.7  60,590  In a hostile, post-pandemic world, Joel and El...    True
# 8     9.2  16,907  Take control of three androids in their quest ...    True
# 9     8.8   8,136  Deliveryman Sam Porter must travel across a ra...    True
#
#    Adventure  Comedy  Crime  Family  Fantasy  Mystery  Sci-Fi  Thriller
# 0       True   False  False   False     True    False   False     False
# 1       True   False   True   False    False    False   False     False
# 2      False   False   True   False    False    False   False     False
# 3       True   False  False   False    False    False   False     False
# 4       True   False  False   False    False    False   False     False
# 5       True   False  False   False    False    False   False     False
# 6       True   False  False   False    False     True   False     False
# 7       True   False  False   False    False    False   False     False
# 8       True   False  False   False    False    False   False     False
# 9       True   False  False   False    False    False   False     False

# %% [markdown]
# - ¿Cúal es el último índice que tenemos en el Dataframe?

# %%
df_video.index[-1]
# Out:
# 20802

# %% [markdown]
# - Mostrar 15 filas aleatorias.

# %%
df_video.sample(15)
# Out:
#                                      name  \
# 8494                          Power Moves
# 3962                         Stronghold 2
# 2286                     Half-Life: Decay
# 19754                     Alien Crossfire
# 19676           Warhammer 40,000 Regicide
# 18538                                Ghox
# 8332                              Railfan
# 19784                      Stunt Racer 64
# 10376                         Machinarium
# 14508                         Word Rescue
# 14335                    Midnight Raiders
# 18815        Hello kitty: Big City Dreams
# 10791  The Pink Panther: Hokus Pokus Pink
# 2044                          Minesweeper
# 17634                              Rapids
#
#                                                      url    year certificate  \
# 8494   https://www.imdb.com/title/tt5797136/?ref_=adv...  1992.0         NaN
# 3962   https://www.imdb.com/title/tt0467493/?ref_=adv...  2005.0         NaN
# 2286   https://www.imdb.com/title/tt5886090/?ref_=adv...  2001.0           M
# 19754  https://www.imdb.com/title/tt0432471/?ref_=adv...  1999.0           E
# 19676  https://www.imdb.com/title/tt5289756/?ref_=adv...  2015.0         NaN
# 18538  https://www.imdb.com/title/tt2543004/?ref_=adv...  1991.0         NaN
# 8332   https://www.imdb.com/title/tt2306958/?ref_=adv...  2006.0         NaN
# 19784  https://www.imdb.com/title/tt5466362/?ref_=adv...  2000.0           E
# 10376  https://www.imdb.com/title/tt2395486/?ref_=adv...  2009.0         NaN
# 14508  https://www.imdb.com/title/tt13039444/?ref_=ad...  1992.0         NaN
# 14335  https://www.imdb.com/title/tt2032498/?ref_=adv...  1994.0         NaN
# 18815  https://www.imdb.com/title/tt21255672/?ref_=ad...  2008.0         NaN
# 10791  https://www.imdb.com/title/tt7467584/?ref_=adv...  1998.0           E
# 2044   https://www.imdb.com/title/tt0285729/?ref_=adv...  1989.0         NaN
# 17634  https://www.imdb.com/title/tt7130422/?ref_=adv...  2016.0         NaN
#
#        rating votes                                               plot  \
# 8494      5.8     6                                         Add a Plot
# 3962      6.9   193  To keep and to develop your castle for gain po...
# 2286      7.3    58  Step into the HEV Suits of Black Mesa scientis...
# 19754     7.5    39                                         Add a Plot
# 19676     6.7    18                                         Add a Plot
# 18538     5.2     9                                         Add a Plot
# 8332      NaN   NaN                                         Add a Plot
# 19784     5.6     6                                         Add a Plot
# 10376     8.1   515  A point-and-click adventure in which a humble ...
# 14508     NaN   NaN                                         Add a Plot
# 14335     NaN   NaN  You get orders to execute a top secret mission...
# 18815     NaN   NaN                                         Add a Plot
# 10791     8.0    11  Traveling salesman Pink Panther must go around...
# 2044      6.5   971  Minesweeper is a single-player puzzle game whe...
# 17634     NaN   NaN                                         Add a Plot
#
#        Action  Adventure  Comedy  Crime  Family  Fantasy  Mystery  Sci-Fi  \
# 8494     True      False   False  False   False    False    False   False
# 3962     True      False   False  False   False    False    False   False
# 2286     True      False   False  False   False    False    False    True
# 19754   False      False   False  False   False    False    False    True
# 19676   False      False   False  False   False    False    False    True
# 18538   False      False   False  False   False     True    False   False
# 8332     True      False   False  False   False    False    False   False
# 19784   False      False   False  False   False    False    False    True
# 10376   False       True   False  False   False    False     True    True
# 14508   False       True   False  False    True    False    False   False
# 14335    True       True   False   True   False    False    False   False
# 18815   False      False   False  False   False     True    False   False
# 10791   False       True    True  False   False    False    False   False
# 2044     True      False   False  False    True    False    False   False
# 17634   False      False   False  False    True    False    False   False
#
#        Thriller
# 8494      False
# 3962      False
# 2286       True
# 19754     False
# 19676     False
# 18538     False
# 8332      False
# 19784     False
# 10376     False
# 14508     False
# 14335     False
# 18815     False
# 10791     False
# 2044      False
# 17634     False

# %% [markdown]
# - Crea una lista con el nombre de las columnas.

# %%
columnas = df_video.columns

# %%
column_list = []
for elemento in columnas:
    column_list.append(elemento)

# %%
print (column_list)
# Out:
# ['name', 'url', 'year', 'certificate', 'rating', 'votes', 'plot', 'Action', 'Adventure', 'Comedy', 'Crime', 'Family', 'Fantasy', 'Mystery', 'Sci-Fi', 'Thriller']

# %% [markdown]
# - Guardar el Dataframe en formato Excel y después crear un Dataframe con el Excel. ¿EL Dataframe es similar al que teníais antes

# %%
df_video.to_excel("video.xlsx")

# %%
df_video = pd.read_excel("video.xlsx", index_col = 0)
df_video
# Out:
#                                       name  \
# 0                               Spider-Man
# 1                   Red Dead Redemption II
# 2                       Grand Theft Auto V
# 3                               God of War
# 4               Uncharted 4: A Thief's End
# ...                                    ...
# 20798  Enjoy Your Power, Enjoy Your Choice
# 20799                           RedSun2020
# 20800                              Shutter
# 20801                    The Music Machine
# 20802                              Cryptic
#
#                                                      url    year certificate  \
# 0      https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1      https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2      https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3      https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4      https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
# ...                                                  ...     ...         ...
# 20798  https://www.imdb.com/title/tt3845606/?ref_=adv...  2014.0         NaN
# 20799  https://www.imdb.com/title/tt0790739/?ref_=adv...  2004.0         NaN
# 20800  https://www.imdb.com/title/tt5119948/?ref_=adv...  2015.0         NaN
# 20801  https://www.imdb.com/title/tt5142082/?ref_=adv...  2015.0         NaN
# 20802  https://www.imdb.com/title/tt10964974/?ref_=ad...  2020.0         NaN
#
#        rating   votes                                               plot  \
# 0         9.2  20,759  When a new villain threatens New York City, Pe...
# 1         9.7  35,703  Amidst the decline of the Wild West at the tur...
# 2         9.5  59,986  Three very different criminals team up for a s...
# 3         9.6  26,118  After wiping out the gods of Mount Olympus, Kr...
# 4         9.5  28,722  Thrown back into the dangerous underworld he'd...
# ...       ...     ...                                                ...
# 20798     NaN     NaN                                         Add a Plot
# 20799     NaN     NaN  Joseph gets kidnapped and it's the player's jo...
# 20800     NaN     NaN  A tech support man who uses a drone to investi...
# 20801     NaN     NaN  A young teenage girl and the ghost of a dead m...
# 20802     NaN     NaN  Kidnapped by an insane man and dragged into a ...
#
#        Action  Adventure  Comedy  Crime  Family  Fantasy  Mystery  Sci-Fi  \
# 0        True       True   False  False   False     True    False   False
# 1        True       True   False   True   False    False    False   False
# 2        True      False   False   True   False    False    False   False
# 3        True       True   False  False   False    False    False   False
# 4        True       True   False  False   False    False    False   False
# ...       ...        ...     ...    ...     ...      ...      ...     ...
# 20798   False      False   False  False   False    False    False   False
# 20799   False      False   False  False   False    False    False   False
# 20800   False      False   False  False   False    False    False   False
# 20801   False      False   False  False   False    False    False   False
# 20802   False      False   False  False   False    False    False   False
#
#        Thriller
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 20798      True
# 20799      True
# 20800      True
# 20801      True
# 20802      True
#
# [20803 rows x 16 columns]

# %% [markdown]
# - Muestra la "info" del Dataframe.

# %%
df_video.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20803 entries, 0 to 20802
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         20803 non-null  object
#  1   url          20803 non-null  object
#  2   year         20536 non-null  float64
#  3   certificate  7903 non-null   object
#  4   rating       11600 non-null  float64
#  5   votes        11600 non-null  object
#  6   plot         20803 non-null  object
#  7   Action       20803 non-null  bool
#  8   Adventure    20803 non-null  bool
#  9   Comedy       20803 non-null  bool
#  10  Crime        20803 non-null  bool
#  11  Family       20803 non-null  bool
#  12  Fantasy      20803 non-null  bool
#  13  Mystery      20803 non-null  bool
#  14  Sci-Fi       20803 non-null  bool
#  15  Thriller     20803 non-null  bool
# dtypes: bool(9), float64(2), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# - ¿Tiene nulos o duplicados?

# %%
df_video.duplicated().sum()
# Out:
# 1

# %%
df_video.isnull().sum()
# Out:
# name               0
# url                0
# year             267
# certificate    12900
# rating          9203
# votes           9203
# plot               0
# Action             0
# Adventure          0
# Comedy             0
# Crime              0
# Family             0
# Fantasy            0
# Mystery            0
# Sci-Fi             0
# Thriller           0
# dtype: int64

# %% [markdown]
# - Obtener la descripción del Dataframe, tanto de las columnas numéricas cómo de las de tipo "object". Explorar el resultado y sacar unas mínimas comclusiones sobre los datos que habéis obtenido.

# %%
df_video.describe(include=object)
# Out:
#               name                                                url  \
# count        20803                                              20803
# unique       19714                                              20157
# top     Spider-Man  https://www.imdb.com/title/tt5807780/?ref_=adv...
# freq             9                                                  4
#
#        certificate  votes        plot
# count         7903  11600       20803
# unique          21   1905       11276
# top              T      7  Add a Plot
# freq          2474    318        8874

# %%
df_video.describe()
# Out:
#                year        rating
# count  20536.000000  11600.000000
# mean    2005.568611      7.047526
# std       11.846028      1.235204
# min     1952.000000      1.000000
# 25%     1997.000000      6.400000
# 50%     2008.000000      7.200000
# 75%     2016.000000      7.900000
# max     2027.000000      9.700000

# %%
df_video.describe(include='all')
# Out:
#               name                                                url  \
# count        20803                                              20803
# unique       19714                                              20157
# top     Spider-Man  https://www.imdb.com/title/tt5807780/?ref_=adv...
# freq             9                                                  4
# mean           NaN                                                NaN
# std            NaN                                                NaN
# min            NaN                                                NaN
# 25%            NaN                                                NaN
# 50%            NaN                                                NaN
# 75%            NaN                                                NaN
# max            NaN                                                NaN
#
#                 year certificate        rating  votes        plot Action  \
# count   20536.000000        7903  11600.000000  11600       20803  20803
# unique           NaN          21           NaN   1905       11276      2
# top              NaN           T           NaN      7  Add a Plot   True
# freq             NaN        2474           NaN    318        8874  11930
# mean     2005.568611         NaN      7.047526    NaN         NaN    NaN
# std        11.846028         NaN      1.235204    NaN         NaN    NaN
# min      1952.000000         NaN      1.000000    NaN         NaN    NaN
# 25%      1997.000000         NaN      6.400000    NaN         NaN    NaN
# 50%      2008.000000         NaN      7.200000    NaN         NaN    NaN
# 75%      2016.000000         NaN      7.900000    NaN         NaN    NaN
# max      2027.000000         NaN      9.700000    NaN         NaN    NaN
#
#        Adventure Comedy  Crime Family Fantasy Mystery Sci-Fi Thriller
# count      20803  20803  20803  20803   20803   20803  20803    20803
# unique         2      2      2      2       2       2      2        2
# top        False  False  False  False   False   False  False    False
# freq       10469  19020  19908  17928   16453   19618  17213    20280
# mean         NaN    NaN    NaN    NaN     NaN     NaN    NaN      NaN
# std          NaN    NaN    NaN    NaN     NaN     NaN    NaN      NaN
# min          NaN    NaN    NaN    NaN     NaN     NaN    NaN      NaN
# 25%          NaN    NaN    NaN    NaN     NaN     NaN    NaN      NaN
# 50%          NaN    NaN    NaN    NaN     NaN     NaN    NaN      NaN
# 75%          NaN    NaN    NaN    NaN     NaN     NaN    NaN      NaN
# max          NaN    NaN    NaN    NaN     NaN     NaN    NaN      NaN

# %% [markdown]
# - Finalmente, guarda el Dataframe en formato "csv" con un nombre diferente del original.

# %%
df_video.to_csv("video_2.csv")
